# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm 
import seaborn as sns
import math 
import itertools
import plotly.graph_objects as go
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.vector_ar.vecm import coint_johansen
from statsmodels.graphics.tsaplots import plot_acf
from datetime import date
import warnings


warnings.filterwarnings('ignore')

# %%
def get_data(): 
    lev_gold_etf = yf.download("3GOL.MI", period = "20y")[["Close", 'Volume']].droplevel(1, axis=1).reset_index()
    gold_etf = yf.download("GLD", period = "20y")[["Close", 'Volume']].droplevel(1, axis=1).reset_index()
    gold_future = yf.download('GC=F', period = "20y")[["Close", 'Volume']].droplevel(1, axis=1).reset_index()

    print(lev_gold_etf.columns, lev_gold_etf.index)
    return lev_gold_etf, gold_etf, gold_future

get_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Index(['Date', 'Close', 'Volume'], dtype='object', name='Price') RangeIndex(start=0, stop=3341, step=1)
# (Price       Date       Close  Volume
#  0     2012-12-20   90.901314       0
#  1     2012-12-21   93.247002       0
#  2     2012-12-27   93.818497       0
#  3     2012-12-28   92.493301       0
#  4     2013-01-02   98.025146       0
#  ...          ...         ...     ...
#  3336  2026-03-02  280.320007   46493
#  3337  2026-03-03  253.089996   48821
#  3338  2026-03-04  257.519989   10948
#  3339  2026-03-05  245.339996   18517
#  3340  2026-03-11  259.899994    5414
#
#  [3341 rows x 3 columns],
#  Price       Date       Close    Volume
#  0     2006-03-13   54.310001   2425700
#  1     2006-03-14   54.869999   2671700
#  2     2006-03-15   55.119999   4706800
# ...
